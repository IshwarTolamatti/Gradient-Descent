# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:\Dump\Ishwar\Data_Science\Edureka\Class 7\Class 7 - Codes\Salary_Data.csv")

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
# YearsExperience    30 non-null float64
# Salary             30 non-null float64
# dtypes: float64(2)
# memory usage: 560.0 bytes

# %%
x = df["YearsExperience"]
x.head()
# Out:
# 0    1.1
# 1    1.3
# 2    1.5
# 3    2.0
# 4    2.2
# Name: YearsExperience, dtype: float64

# %%
y = df["Salary"]
y.head()
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Salary, dtype: float64

# %%
plt.scatter(x,y)

# %%
x=x.values.reshape(-1, 1)
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y=y.values.reshape(-1, 1)
y
# Out:
# array([[ 39343.],
#        [ 46205.],
#        [ 37731.],
#        [ 43525.],
#        [ 39891.],
#        [ 56642.],
#        [ 60150.],
#        [ 54445.],
#        [ 64445.],
#        [ 57189.],
#        [ 63218.],
#        [ 55794.],
#        [ 56957.],
#        [ 57081.],
#        [ 61111.],
#        [ 67938.],
#        [ 66029.],
#        [ 83088.],
#        [ 81363.],
#        [ 93940.],
#        [ 91738.],
#        [ 98273.],
#        [101302.],
#        [113812.],
#        [109431.],
#        [105582.],
#        [116969.],
#        [112635.],
#        [122391.],
#        [121872.]])

# %% [markdown]
# # Gradient Descent:

# %%
"""

In Gradient Descent we get the value of m and b for lowest value of cost function. Cost function is also called as 
error function which should be minimum.

"""
# Out:
# '\n\nIn Gradient Descent we get the value of m and b for lowest value of cost function. Cost function is also called as \nerror function which should be minimum.\n\n'

# %%
def gradient_descent(x,y):
    m_curr = b_curr = [0]
    cost_f = [0]
    iterations = 3000
    n = len(x)
    learning_rate = 0.01
    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        cost_f.append(cost)
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))
    plt.plot(cost_f)
gradient_descent(x,y)
# Out:
# m [9547.974], b [1520.06], cost [6.50295527e+09] iteration 0
# m [12056.69235267], b [1995.0874296], cost [5.95473385e+08] iteration 1
# m [12707.81767044], b [2194.02117366], cost [1.83107993e+08] iteration 2
# m [12868.77569178], b [2319.78332575], cost [1.53439943e+08] iteration 3
# m [12900.42596039], b [2425.92576238], cost [1.5043161e+08] iteration 4
# m [12897.99808257], b [2526.58198175], cost [1.49287859e+08] iteration 5
# m [12886.62268517], b [2625.4830792], cost [1.48281849e+08] iteration 6
# m [12872.93147573], b [2723.61498028], cost [1.47293253e+08] iteration 7
# m [12858.67435081], b [2821.23916252], cost [1.46313625e+08] iteration 8
# m [12844.31291177], b [2918.42591825], cost [1.45342311e+08] iteration 9
# m [12829.96878341], b [3015.19508113], cost [1.44379201e+08] iteration 10
# m [12815.67387247], b [3111.55316346], cost [1.43424223e+08] iteration 11
# m [12801.43641017], b [3207.50315667], cost [1.42477308e+08] iteration 12
# ...

# %%
# y= mx+c -------From ablove we get to know that:  m(co-efficient)=~9449, b(intercept)=~25792

# %%
# Lets compare Gradient Descent with Linear Regression in Scikit Learn

# %% [markdown]
# # Linear Regression (Scikit Learn):

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lr.coef_
# Out:
# array([[9449.96232146]])

# %%
lr.intercept_
# Out:
# array([25792.20019867])

# %%
# y= mx+c -------From ablove we get to know that:  m(co-efficient)=~9449, b(intercept)=~25792
